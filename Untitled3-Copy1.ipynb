# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import matplotlib.pyplot as plt

# %%
assignaturesNoIni=[240031,240032,240033,240131,240132,240133,240041,240042,240043,240141]
Preinscripcio = pd.read_csv('./dpersnomespreinsc18.csv',sep=';')
FaseIni = pd.read_csv('./qfaseini18.csv',sep=';')
FaseNoIni = pd.read_csv('./qfasenoini18.csv',sep=';', low_memory = False)

# %%
#ini_comu = ini_originals[ini_originals.CODEX.isin(nini_originals.CODEX)]
#nini_comu = nini_originals[nini_originals.CODEX.isin(ini_originals.CODEX)]
#notes = ini_comu.append(nini_comu, ignore_index=True)
#notessele = notes[notes.CODEX.isin(sele_originals.CODEX)]
FaseIni_comuns = FaseIni[FaseIni.CODEX.isin(FaseNoIni.CODEX)]

FaseNoIni_comuns = FaseNoIni[FaseNoIni.CODEX.isin(FaseIni_comuns.CODEX)]
FaseIni_comuns = FaseIni_comuns[FaseIni_comuns.CODEX.isin(FaseNoIni_comuns.CODEX)]

notes = FaseIni_comuns.append(FaseNoIni_comuns , ignore_index = True)

#notesele = notes[notes.CODEX.isin(Preinscripcio.CODEX)]

# %%
#FaseIni_comuns.groupby('CODEX').count()
a =FaseIni_comuns.groupby(['CODEX','CODASS']).size()
a
a.to_frame()
a =FaseIni_comuns.groupby(['CODEX','CODASS']).size().groupby('CODEX').agg({'size':sum})
lospros=a[a['size']==10].index.values
losbuenos=a[a['size']==11].index.values
losmedios=a[((a['size']>=12)&(a['size']<=15))].index.values
lospringuers=a[(a['size']>15)].index.values

NotasIniPros=FaseIni_comuns[(FaseIni_comuns['CODEX'].isin(lospros)&(FaseIni_comuns['NF']>=5))]
NotasIniBuenos=FaseIni_comuns[FaseIni_comuns['CODEX'].isin(losbuenos)]
NotasIniMedios=FaseIni_comuns[FaseIni_comuns['CODEX'].isin(losmedios)]
NotasIniPringuers=FaseIni_comuns[FaseIni_comuns['CODEX'].isin(lospringuers)]

#NotasIniPringuers=FaseIni_comuns[((FaseIni_comuns['CODEX'].isin(lospringuers))&(FaseIni_comuns['NF']>=5))]

NotasNoIniPros=FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(lospros)]
NotasNoIniBuenos=FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(losbuenos)]
NotasNoIniMedios=FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(losmedios)]
NotasNoIniPringuers=FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(lospringuers)]


NotasIniPros.groupby(['CODASS']).agg({'NF':'mean'})
NotasIniBuenos.groupby(['CODASS']).agg({'NF':'mean'})
NotasIniMedios.groupby(['CODASS']).agg({'NF':'mean'})
NotasIniPringuers.groupby(['CODASS']).agg({'NF':'mean'})
#https://matplotlib.org/gallery/statistics/boxplot_demo.html
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240011]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240012]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240013]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240014]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240015]['NF'])
# Out:
# /Users/Jordi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """
#               NF
# CODASS
# 240011  4.590548
# 240012  4.695402
# 240013  4.641985
# 240014  4.992166
# 240015  4.356387
# 240021  4.652104
# 240022  4.427733
# 240023  4.173730
# 240024  4.940181
# 240025  4.657080

# %%
zzz = NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box()

# %%
zzz = NotasIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box()

# %%
zzz = NotasIniMedios.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')

zzz.plot.box(figsize=(8,5))
plt.savefig('sample.jpg')
zzz = NotasIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box()

# %%
zzz = NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup1.jpg')
zzz = NotasIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup2.jpg')
zzz = NotasIniMedios.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup3.jpg')
zzz = NotasIniPringuers.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup4.jpg')

# %%
zzz = NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz[240015].sort_values()
# Out:
# CODEX
# 252404     3.95
# 259044     5.00
# 256131     5.00
# 256803     5.00
# 229691     5.00
# 229423     5.00
# 228880     5.00
# 277484     5.00
# 258563     5.00
# 261141     5.00
# 277628     5.00
# 228179     5.00
# 228128     5.00
# 277881     5.00
# 259702     5.00
# 278713     5.00
# 227707     5.00
# 278723     5.00
# 288976     5.00
# 278728     5.00
# 248715     5.00
# 231991     5.00
# 273938     5.00
# 264725     5.00
# 263878     5.00
# 274958     5.00
# 262671     5.00
# 244596     5.00
# 262666     5.00
# 244151     5.00
#           ...
# 276760    10.00
# 276787    10.00
# 276856    10.00
# 284275    10.00
# 276968    10.00
# 275156    10.00
# 276511    10.00
# 275117    10.00
# 274930    10.00
# 278720    10.00
# 259886    10.00
# 260879    10.00
# 261577    10.00
# 259337    10.00
# 259155    10.00
# 261789    10.00
# 258997    10.00
# 260383    10.00
# 262923    10.00
# 256153    10.00
# 273903    10.00
# 273905    10.00
# 273958    10.00
# 274054    10.00
# ...

# %%
assignaturesNoIni=['240031','240032','240033','240131','240132','240133','240041','240042','240043','240141']

NotasNoIniProsfiltered=NotasNoIniPros[NotasNoIniPros['CODASS'].isin(assignaturesNoIni)]
# Out:
# 76       240042
# 79       240033
# 82       240043
# 84       240133
# 86       240132
# 88       240141
# 97       240032
# 99       240031
# 100      240041
# 103      240131
# 294      240042
# 296      240141
# 302      240032
# 304      240031
# 306      240043
# 308      240133
# 310      240033
# 313      240132
# 315      240131
# 317      240041
# 321      240043
# 324      240041
# 326      240042
# 333      240032
# 335      240033
# 338      240131
# 339      240133
# 340      240132
# 341      240031
# 349      240141
#           ...
# 65407    240132
# 65409    240133
# 65411    240131
# 65412    240032
# 65419    240033
# 65420    240042
# 65423    240043
# 65424    240141
# 65426    240133
# 65427    240031
# 65429    240032
# 65430    240132
# 65432    240031
# 65433    240042
# 65435    240041
# 65437    240131
# 65442    240031
# 65443    240133
# 65446    240133
# 65447    240132
# 65448    240141
# 65454    240033
# 65455    240043
# 65456    240031
# ...

# %%
achu=NotasNoIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
achu[assignaturesNoIni].plot.box()

# %%
from pandas.plotting import scatter_matrix

#assignaturesNoIni= ['Electromag','Met. Numerics','Materials','Eq. Diferencials','Informatica','Mecanica','Economia','Estadistica','Dinamica','T. de maquines']

#achu=NotasNoIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#achu2=achu.rename({'240031':'Electromag', '240032':'Met. Numerics', '240033':'Materials', '240131':'Eq. Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia', '240042':'Estadistica', '240043':'Dinamica', '240141':'T. de maquines'}, axis='columns')
#achu2[assignaturesNoIni].plot.scatter_matrix(figsize=(13,5))
#scatter_matrix(achu2[assignaturesNoIni], alpha=0.2, figsize=(12, 12), diagonal='kde')
#plt.savefig('Grup1NoIScatter.jpg')
achu=NotasNoIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
achu2=achu.rename({'240031':'Electromag', '240032':'Met. Numerics', '240033':'Materials', '240131':'Eq. Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia', '240042':'Estadistica', '240043':'Dinamica', '240141':'T. de maquines'}, axis='columns')
scatter_matrix(achu2[assignaturesNoIni], alpha=0.2, figsize=(12, 12), diagonal='kde')
#achu2[assignaturesNoIni].plot.box(figsize=(13,5))
plt.savefig('Grup2NoIscatter.jpg')
#achu=NotasNoIniMedios.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#achu2=achu.rename({'240031':'Electromag', '240032':'Met. Numerics', '240033':'Materials', '240131':'Eq. Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia', '240042':'Estadistica', '240043':'Dinamica', '240141':'T. de maquines'}, axis='columns')
#scatter_matrix(achu2[assignaturesNoIni], alpha=0.2, figsize=(12, 12), diagonal='kde')
#plt.savefig('Grup3NoIscatter.jpg')
#achu2[assignaturesNoIni].plot.box(figsize=(13,5))
#plt.savefig('Grup3NoI.jpg')
#achu=NotasNoIniPringuers.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#achu2=achu.rename({'240031':'Electromag', '240032':'Met. Numerics', '240033':'Materials', '240131':'Eq. Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia', '240042':'Estadistica', '240043':'Dinamica', '240141':'T. de maquines'}, axis='columns')
#scatter_matrix(achu2[assignaturesNoIni], alpha=0.2, figsize=(12, 12), diagonal='kde')
#achu2[assignaturesNoIni].plot.box(figsize=(13,5))
#plt.savefig('Grup4NoIscatter.jpg')

#plt.savefig('Grup4NoI.jpg')

# %%
#achu=NotasNoIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#achu2=achu.rename({'240031':'Electromagnetisme', '240032':'Metodes Numerics', '240033':'Materials', '240131':'Equacions Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia i empresa', '240042':'Estadistica', '240043':'Dinamica de sistemes', '240141':'Teoria de maquines'}, axis='columns')

# %%
#zzz = NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#zzz.plot.box(figsize=(8,5))
#plt.savefig('Grup1.jpg')
#zzz = NotasIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#zzz.plot.box(figsize=(8,5))
#plt.savefig('Grup2.jpg')
#zzz = NotasIniMedios.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#zzz.plot.box(figsize=(8,5))
#plt.savefig('Grup3.jpg')
#zzz = NotasIniPringuers.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#zzz.plot.box(figsize=(8,5))
#plt.savefig('Grup4.jpg')
listado=[]
Info=NotasIniPringuers.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
listado.append(Info[240015].mean())
achu=NotasNoIniPringuers.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
achu2=achu.rename({'240031':'Electromag', '240032':'Met. Numerics', '240033':'Materials', '240131':'Eq. Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia', '240042':'Estadistica', '240043':'Dinamica', '240141':'T. de maquines'}, axis='columns')
listado.append(achu2['Informatica'].mean())
listado
# Out:
# [4.820457280385077, 5.017169811320754]

# %%
n=len(listado)
x=range(n)
width=1/5
plt.bar(x,listado,width)
plt.show()

# %%
from pandas.plotting import scatter_matrix
#a=FaseIni_comuns.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#scatter_matrix(a, alpha=0.2, figsize=(12, 12), diagonal='kde')

a=NotasNoIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
achu2=a.rename({'240031':'Electromag', '240032':'Met. Numerics', '240033':'Materials', '240131':'Eq. Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia', '240042':'Estadistica', '240043':'Dinamica', '240141':'T. de maquines'}, axis='columns')
scatter_matrix(achu2[assignaturesNoIni], alpha=0.2, figsize=(12, 12), diagonal='kde')

# %%
pivot1=NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
pivot2=NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')

#pd.merge(pivot1,pivot2,on='CODEX')
#dat=[NotasIniPros,NotasNoIniPros]
assignaturesNoIni=['240031','240032','240033','240131','240132','240133','240041','240042','240043','240141']

#AA=pivot1.append(pivot2)
#aa=pivot2[assignaturesNoIni]

#AA=pd.merge(pivot1,aa,on='CODEX')
#result= pd.merge(NotasIniPros,NotasIniPros,on='CODEX',how='outer')
#x=result.pivot_table(index='CODEX',columns='CODASS_y',values='NF_y')
aa=NotasIniPros.append(NotasNoIniPros)
aa.CODEX =aa.CODEX.to_string()
#df.column_name = df.column_name.astype(str)
pivot3=aa.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
writer = pd.ExcelWriter('output.xlsx')
pivot3.to_excel(writer,'Sheet1')
writer.save()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-1b779c148bf2> in <module>()
#      15 aa.CODEX =aa.CODEX.to_string()
#      16 #df.column_name = df.column_name.astype(str)
# ---> 17 pivot3=aa.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
#      18 writer = pd.ExcelWriter('output.xlsx')
#      19 pivot3.to_excel(writer,'Sheet1')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    4466                            aggfunc=aggfunc, fill_value=fill_value,
#    4467                            margins=margins, dropna=dropna,
# -> 4468                            margins_name=margins_name)
#    4469
#    4470     def stack(self, level=-1, dropna=True):
#
# ...
