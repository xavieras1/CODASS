# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import matplotlib.pyplot as plt

# %%
Preinscripcio = pd.read_csv('./dpersnomespreinsc18.csv',sep=';')
FaseIni = pd.read_csv('./qfaseini18.csv',sep=';')
FaseNoIni = pd.read_csv('./qfasenoini18.csv',sep=';', low_memory = False)

#achu2=achu.rename({'240031':'Electromag', '240032':'Met. Numerics', '240033':'Materials', '240131':'Eq. Diferencials', '240132':'Informatica','240133':'Mecanica', '240041':'Economia', '240042':'Estadistica', '240043':'Dinamica', '240141':'T. de maquines'}, axis='columns')
FaseIni_comuns = FaseIni[FaseIni.CODEX.isin(FaseNoIni.CODEX)]
FaseNoIni = FaseNoIni[FaseNoIni.CODASS.isin(['240031', '240032', '240033', '240131', '240132','240133', '240041', '240042', '240043', '240141'])]

# %%
#ini_comu = ini_originals[ini_originals.CODEX.isin(nini_originals.CODEX)]
#nini_comu = nini_originals[nini_originals.CODEX.isin(ini_originals.CODEX)]
#notes = ini_comu.append(nini_comu, ignore_index=True)
#notessele = notes[notes.CODEX.isin(sele_originals.CODEX)]

FaseIni_comuns = FaseIni[FaseIni.CODEX.isin(FaseNoIni.CODEX)]

FaseNoIni_comuns = FaseNoIni[FaseNoIni.CODEX.isin(FaseIni_comuns.CODEX)]
FaseIni_comuns = FaseIni_comuns[FaseIni_comuns.CODEX.isin(FaseNoIni_comuns.CODEX)]

#notes = FaseIni_comuns.append(FaseNoIni_comuns , ignore_index = True)

#notesele = notes[notes.CODEX.isin(Preinscripcio.CODEX)]

# %%
#FaseIni_comuns.groupby('CODEX').count()
a = FaseIni_comuns.groupby(['CODEX','CODASS']).size()
a
a.to_frame()
a = FaseIni_comuns.groupby(['CODEX','CODASS']).size().groupby('CODEX').agg({'size':sum})
lospros = a[a['size']==10].index.values
losbuenos = a[a['size']==11].index.values
losmedios = a[((a['size']>=12)&(a['size']<=15))].index.values
lospringuers = a[(a['size']>15)].index.values

IniPros = FaseIni_comuns[(FaseIni_comuns['CODEX'].isin(lospros)&(FaseIni_comuns['NF']>=5))]
IniBuenos = FaseIni_comuns[FaseIni_comuns['CODEX'].isin(losbuenos)]
IniMedios = FaseIni_comuns[FaseIni_comuns['CODEX'].isin(losmedios)]
IniPringuers = FaseIni_comuns[FaseIni_comuns['CODEX'].isin(lospringuers)]

#NotasIniPringuers=FaseIni_comuns[((FaseIni_comuns['CODEX'].isin(lospringuers))&(FaseIni_comuns['NF']>=5))]

NoIniPros = FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(lospros) ]
NoIniBuenos =FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(losbuenos)]
NoIniMedios = FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(losmedios)]
NoIniPringuers = FaseNoIni_comuns[FaseNoIni_comuns['CODEX'].isin(lospringuers)]


IniPros.groupby(['CODASS']).agg({'NF':'mean'})
IniBuenos.groupby(['CODASS']).agg({'NF':'mean'})
IniMedios.groupby(['CODASS']).agg({'NF':'mean'})
IniPringuers.groupby(['CODASS']).agg({'NF':'mean'})
#https://matplotlib.org/gallery/statistics/boxplot_demo.html
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240011]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240012]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240013]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240014]['NF'])
#plt.boxplot(NotasIniPros[NotasIniPros['CODASS']==240015]['NF'])

for ini,noini in zip([lospros,losbuenos,losmedios,lospringuers],[NoIniPros,NoIniBuenos,NoIniMedios,NoIniPringuers]):
    b = noini.groupby(['CODEX','CODASS']).size().groupby('CODEX').agg({'size':sum})
    pres = b[b['size']<10].index.values
    pros = b[b['size']==10].index.values
    buenos = b[b['size']==11].index.values
    medios = b[((b['size']>=12)&(b['size']<=15))].index.values
    pringuers = b[(b['size']>15)].index.values
    print(ini.shape,pres.shape,pros.shape,buenos.shape,medios.shape,pringuers.shape)   
    

#print(IniPros.shape,NoIniPros.shape,)
#print(IniBuenos.shape,NoIniBuenos.shape,)
#print(IniMedios.shape,NoIniMedios.shape,)
#print(IniPringuers.shape,NoIniPringuers.shape,)
# Out:
# (765,) (16,) (383,) (172,) (167,) (27,)
# (181,) (1,) (50,) (36,) (76,) (18,)
# (644,) (16,) (90,) (112,) (275,) (151,)
# (277,) (17,) (10,) (11,) (114,) (125,)
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version

# %%
zzz = NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box()

# %%
zzz = NotasIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box()

# %%
zzz = NotasIniMedios.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')

zzz.plot.box(figsize=(8,5))
plt.savefig('sample.jpg')
zzz = NotasIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box()

# %%
zzz = NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup1.jpg')
zzz = NotasIniBuenos.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup2.jpg')
zzz = NotasIniMedios.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup3.jpg')
zzz = NotasIniPringuers.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz.plot.box(figsize=(8,5))
plt.savefig('Grup4.jpg')

# %%
zzz = NotasIniPros.pivot_table(index= 'CODEX',columns= 'CODASS',values ='NF')
zzz[240015].sort_values()
# Out:
# CODEX
# 252404     3.95
# 259044     5.00
# 256131     5.00
# 256803     5.00
# 229691     5.00
# 229423     5.00
# 228880     5.00
# 277484     5.00
# 258563     5.00
# 261141     5.00
# 277628     5.00
# 228179     5.00
# 228128     5.00
# 277881     5.00
# 259702     5.00
# 278713     5.00
# 227707     5.00
# 278723     5.00
# 288976     5.00
# 278728     5.00
# 248715     5.00
# 231991     5.00
# 273938     5.00
# 264725     5.00
# 263878     5.00
# 274958     5.00
# 262671     5.00
# 244596     5.00
# 262666     5.00
# 244151     5.00
#           ...
